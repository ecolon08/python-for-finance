# %% [markdown]
# ## Logarithmic Returns

# %%
from datetime import datetime

import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

import yfinance as yf
yf.pdr_override()

# %%
PG = wb.get_data_yahoo('PG', datetime(1995, 1, 1))
PG
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1995-01-03   15.468750   15.625000   15.437500   15.593750    7.771262
# 1995-01-04   15.531250   15.656250   15.312500   15.468750    7.708964
# 1995-01-05   15.375000   15.437500   15.218750   15.250000    7.599946
# 1995-01-06   15.156250   15.406250   15.156250   15.281250    7.615520
# 1995-01-09   15.343750   15.406250   15.187500   15.218750    7.584377
# ...                ...         ...         ...         ...         ...
# 2023-03-06  140.729996  141.139999  139.940002  140.350006  140.350006
# 2023-03-07  140.429993  140.619995  137.339996  137.559998  137.559998
# 2023-03-08  137.199997  137.690002  136.600006  137.580002  137.580002
# 2023-03-09  138.149994  138.559998  136.100006  136.570007  136.570007
# 2023-03-10  136.949997  137.990005  136.350006  137.190002  137.190002
#
#              Volume
# Date
# 1995-01-03  3318400
# 1995-01-04  2218800
# 1995-01-05  2319600
# 1995-01-06  3438000
# 1995-01-09  1795200
# ...             ...
# 2023-03-06  4943100
# 2023-03-07  5606800
# 2023-03-08  5518800
# 2023-03-09  4467200
# 2023-03-10  5908500
#
# [7097 rows x 6 columns]

# %% [markdown]
# ### Log Returns
#
# $$
# ln(\frac{P_t}{P_{t-1}})
# $$

# %%
PG['log_return'] = np.log(PG['Adj Close'] / PG['Adj Close'].shift(1))
print(PG['log_return'])
# Out:
# Date
# 1995-01-03         NaN
# 1995-01-04   -0.008049
# 1995-01-05   -0.014243
# 1995-01-06    0.002047
# 1995-01-09   -0.004098
#                 ...
# 2023-03-06   -0.004266
# 2023-03-07   -0.020079
# 2023-03-08    0.000145
# 2023-03-09   -0.007368
# 2023-03-10    0.004529
# Name: log_return, Length: 7097, dtype: float64

# %%
PG['log_return'].plot(figsize=(8, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
log_return_d = PG['log_return'].mean()
log_return_d
# Out:
# 0.0004045848806380594

# %%
log_return_a = PG['log_return'].mean() * 250
log_return_a
# Out:
# 0.10114622015951485

# %%
print(f"{round(log_return_a, 5) * 100} %")
# Out:
# 10.115 %
